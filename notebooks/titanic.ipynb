# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('seaice')
df.head()
# Out:
#         Date  Extent
# 0 1980-01-01  14.200
# 1 1980-01-03  14.302
# 2 1980-01-05  14.414
# 3 1980-01-07  14.518
# 4 1980-01-09  14.594

# %%
df.shape
# Out:
# (13175, 2)

# %%
# df.to_csv('../datasets/sns/titanic.csv')
