# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_excel('C:/Users/user/Documents/DATA_ANALYSIS/Python_Data/datasets/stock market prices/Historical Stock Market Prices.xlsx','Apple Inc')
df.head(5)
# Out:
#                      Date    Open    High     Low   Close    Volume
# 0 2024-07-01 16:00:00.288  212.09  217.51  211.92  216.75  60402929
# 1 2024-07-02 16:00:00.288  216.15  220.38  215.10  220.27  58046178
# 2 2024-07-03 13:05:00.096  220.00  221.55  219.03  221.55  37369801
# 3 2024-07-05 16:00:00.288  221.65  226.45  221.65  226.34  60412408
# 4 2024-07-08 16:00:00.288  227.09  227.85  223.25  227.82  59085861

# %%
df.shape
# Out:
# (263, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 263 entries, 0 to 262
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    263 non-null    datetime64[ns]
#  1   Open    263 non-null    float64
#  2   High    263 non-null    float64
#  3   Low     263 non-null    float64
#  4   Close   263 non-null    float64
#  5   Volume  263 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 12.5 KB

# %%
df.set_index('Date',inplace=True)

# %% [markdown]
# ##### 1. Datetime Index
# ##### 2. Resample

# %%
df[:5]
# Out:
#                            Open    High     Low   Close    Volume
# Date
# 2024-07-01 16:00:00.288  212.09  217.51  211.92  216.75  60402929
# 2024-07-02 16:00:00.288  216.15  220.38  215.10  220.27  58046178
# 2024-07-03 13:05:00.096  220.00  221.55  219.03  221.55  37369801
# 2024-07-05 16:00:00.288  221.65  226.45  221.65  226.34  60412408
# 2024-07-08 16:00:00.288  227.09  227.85  223.25  227.82  59085861

# %%
df.index
# Out:
# DatetimeIndex(['2024-07-01 16:00:00.288000', '2024-07-02 16:00:00.288000',
#                '2024-07-03 13:05:00.096000', '2024-07-05 16:00:00.288000',
#                '2024-07-08 16:00:00.288000', '2024-07-09 16:00:00.288000',
#                '2024-07-10 16:00:00.288000', '2024-07-11 16:00:00.288000',
#                '2024-07-12 16:00:00.288000', '2024-07-15 16:00:00.288000',
#                ...
#                '2025-07-07 16:00:00.288000', '2025-07-08 16:00:00.288000',
#                '2025-07-09 16:00:00.288000', '2025-07-10 16:00:00.288000',
#                '2025-07-11 16:00:00.288000', '2025-07-14 16:00:00.288000',
#                '2025-07-15 16:00:00.288000', '2025-07-16 16:00:00.288000',
#                '2025-07-17 16:00:00.288000', '2025-07-18 16:00:00.288000'],
#               dtype='datetime64[ns]', name='Date', length=263, freq=None)

# %% [markdown]
# ##### Retrieving partial data - July stoock prices
# ##### The first step when querying a subset of data is to sort the index and then use the `loc()` function

# %%
df.sort_index(inplace=True)

# %%
df.loc['2024-07']
# Out:
#                            Open    High     Low   Close    Volume
# Date
# 2024-07-01 16:00:00.288  212.09  217.51  211.92  216.75  60402929
# 2024-07-02 16:00:00.288  216.15  220.38  215.10  220.27  58046178
# 2024-07-03 13:05:00.096  220.00  221.55  219.03  221.55  37369801
# 2024-07-05 16:00:00.288  221.65  226.45  221.65  226.34  60412408
# 2024-07-08 16:00:00.288  227.09  227.85  223.25  227.82  59085861
# 2024-07-09 16:00:00.288  227.93  229.40  226.37  228.68  48169822
# 2024-07-10 16:00:00.288  229.30  233.08  229.25  232.98  62627687
# 2024-07-11 16:00:00.288  231.39  232.39  225.77  227.57  64710617
# 2024-07-12 16:00:00.288  228.92  232.64  228.68  230.54  53046527
# 2024-07-15 16:00:00.288  236.48  237.23  233.09  234.40  62631252
# 2024-07-16 16:00:00.288  235.00  236.27  232.33  234.82  43234278
# 2024-07-17 16:00:00.288  229.45  231.46  226.64  228.88  57345884
# 2024-07-18 16:00:00.288  230.28  230.44  222.27  224.18  66034585
# 2024-07-19 16:00:00.288  224.82  226.80  223.28  224.31  49151453
# 2024-07-22 16:00:00.288  227.01  227.78  223.09  223.96  48201835
# 2024-07-23 16:00:00.288  224.37  226.94  222.68  225.01  39960260
# 2024-07-24 16:00:00.288  224.00  224.80  217.13  218.54  61777576
# 2024-07-25 16:00:00.288  218.93  220.85  214.62  217.49  51391199
# 2024-07-26 16:00:00.288  218.70  219.49  216.01  217.96  41601345
# 2024-07-29 16:00:00.288  216.96  219.30  215.75  218.24  36311778
# 2024-07-30 16:00:00.288  219.19  220.33  216.12  218.80  41643840
# 2024-07-31 16:00:00.288  221.44  223.82  220.63  222.08  50036262

# %%
df['2024-09-01':'2024-09-30']
# Out:
#                            Open    High     Low   Close     Volume
# Date
# 2024-09-03 16:00:00.288  228.55  229.00  221.17  222.77   50190574
# 2024-09-04 16:00:00.288  221.66  221.78  217.48  220.85   43840196
# 2024-09-05 16:00:00.288  221.63  225.48  221.52  222.38   36615398
# 2024-09-06 16:00:00.288  223.95  225.24  219.77  220.82   48423011
# 2024-09-09 16:00:00.288  220.82  221.27  216.71  220.91   67179965
# 2024-09-10 16:00:00.288  218.92  221.48  216.73  220.11   51591033
# 2024-09-11 16:00:00.288  221.46  223.09  217.89  222.66   44587072
# 2024-09-12 16:00:00.288  222.50  223.55  219.82  222.77   37498225
# 2024-09-13 16:00:00.288  223.58  224.04  221.91  222.50   36766619
# 2024-09-16 16:00:00.288  216.54  217.22  213.92  216.32   59357427
# 2024-09-17 16:00:00.288  215.75  216.90  214.50  216.79   45519339
# 2024-09-18 16:00:00.288  217.55  222.71  217.54  220.69   59894928
# 2024-09-19 16:00:00.288  224.99  229.82  224.63  228.87   66781315
# 2024-09-20 16:00:00.288  229.97  233.09  227.62  228.20  318679888
# 2024-09-23 16:00:00.288  227.34  229.45  225.81  226.47   54146023
# 2024-09-24 16:00:00.288  228.65  229.35  225.73  227.37   43556068
# 2024-09-25 16:00:00.288  224.93  227.29  224.02  226.37   42308715
# 2024-09-26 16:00:00.288  227.30  228.50  225.41  227.52   36636707
# 2024-09-27 16:00:00.288  228.46  229.52  227.30  227.79   34025967
# 2024-09-30 16:00:00.288  230.04  233.00  229.65  233.00   54793391

# %% [markdown]
# + The time series for the closing price for the month of August

# %%
df.loc['2024-08']['Close']
# Out:
# Date
# 2024-08-01 16:00:00.288    218.36
# 2024-08-02 16:00:00.288    219.86
# 2024-08-05 16:00:00.288    209.27
# 2024-08-06 16:00:00.288    207.23
# 2024-08-07 16:00:00.288    209.82
# 2024-08-08 16:00:00.288    213.31
# 2024-08-09 16:00:00.288    216.24
# 2024-08-12 16:00:00.288    217.53
# 2024-08-13 16:00:00.288    221.27
# 2024-08-14 16:00:00.288    221.72
# 2024-08-15 16:00:00.288    224.72
# 2024-08-16 16:00:00.288    226.05
# 2024-08-19 16:00:00.288    225.89
# 2024-08-20 16:00:00.288    226.51
# 2024-08-21 16:00:00.288    226.40
# 2024-08-22 16:00:00.288    224.53
# 2024-08-23 16:00:00.288    226.84
# 2024-08-26 16:00:00.288    227.18
# 2024-08-27 16:00:00.288    228.03
# 2024-08-28 16:00:00.288    226.49
# 2024-08-29 16:00:00.288    229.79
# 2024-08-30 16:00:00.288    229.00
# Name: Close, dtype: float64

# %% [markdown]
# + Finding the mean of the 'Close' prices for August 2024 on the Apple stock prices data

# %%
df.loc['2024-08']['Close'].mean()
# Out:
# 221.6381818181818

# %%
df.loc['2024-09-27']
# Out:
#                            Open    High    Low   Close    Volume
# Date
# 2024-09-27 16:00:00.288  228.46  229.52  227.3  227.79  34025967

# %%
df.loc['2024-10-01':'2024-10-31']
# Out:
#                            Open    High     Low   Close    Volume
# Date
# 2024-10-01 16:00:00.288  229.52  229.65  223.74  226.21  63285048
# 2024-10-02 16:00:00.288  225.89  227.37  223.02  226.78  32880605
# 2024-10-03 16:00:00.288  225.14  226.81  223.32  225.67  34044158
# 2024-10-04 16:00:00.288  227.90  228.00  224.13  226.80  37345098
# 2024-10-07 16:00:00.288  224.50  225.69  221.33  221.69  39505354
# 2024-10-08 16:00:00.288  224.30  225.98  223.25  225.77  31855693
# 2024-10-09 16:00:00.288  225.23  229.75  224.83  229.54  33591091
# 2024-10-10 16:00:00.288  227.78  229.50  227.17  229.04  28183544
# 2024-10-11 16:00:00.288  229.30  229.41  227.34  227.55  31759188
# 2024-10-14 16:00:00.288  228.70  231.73  228.60  231.30  39882085
# 2024-10-15 16:00:00.288  233.61  237.49  232.37  233.85  64751367
# 2024-10-16 16:00:00.288  231.60  232.12  229.84  231.78  34082240
# 2024-10-17 16:00:00.288  233.43  233.85  230.52  232.15  32993810
# 2024-10-18 16:00:00.288  236.18  236.18  234.01  235.00  46431472
# 2024-10-21 16:00:00.288  234.45  236.85  234.45  236.48  36254470
# 2024-10-22 16:00:00.288  233.89  236.22  232.60  235.86  38846578
# 2024-10-23 16:00:00.288  234.08  235.14  227.76  230.76  52286979
# 2024-10-24 16:00:00.288  229.98  230.82  228.41  230.57  31109503
# 2024-10-25 16:00:00.288  229.74  233.22  229.57  231.41  38802304
# 2024-10-28 16:00:00.288  233.32  234.73  232.55  233.40  36087134
# 2024-10-29 16:00:00.288  233.10  234.33  232.32  233.67  35417247
# 2024-10-30 16:00:00.288  232.61  233.47  229.55  230.10  47070907
# 2024-10-31 16:00:00.288  229.34  229.83  225.37  225.91  64370086

# %%
df.index.min()
# Out:
# Timestamp('2024-07-01 16:00:00.288000')

# %% [markdown]
# ##### Resampling time-series data
# + the stock price dataset has daily data for the Apple stock prices, our analysis could require us to query for example monthly data
# + `Pandas.DataFrame.resample` is a convenient method for frequency conversion and resampling of time series. The object must have a datetime-like index

# %%
df['Close'].resample('ME').mean()
# Out:
# Date
# 2024-07-31    224.598636
# 2024-08-31    221.638182
# 2024-09-30    223.758000
# 2024-10-31    230.056087
# 2024-11-30    227.810500
# 2024-12-31    249.322857
# 2025-01-31    234.587000
# 2025-02-28    238.513684
# 2025-03-31    222.702857
# 2025-04-30    201.183810
# 2025-05-31    203.981905
# 2025-06-30    200.657000
# 2025-07-31    210.582308
# Freq: ME, Name: Close, dtype: float64

# %%
df['Close'].resample('ME').mean().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
plt.plot(df['Close'].resample('ME').mean(), marker='*', linestyle='-.', color='orangered')
plt.title('Monthly Average Closing Price of Apple Stock')
plt.xlabel('Month')
plt.ylabel('Average Closing Price')
plt.show()

# %%
df['Close'].plot(color='orangered')
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# #### Date range

# %%
df1=pd.read_excel('C:/Users/user/Documents/DATA_ANALYSIS/Python_Data/datasets/stock market prices/Historical Stock Market Prices.xlsx','Tesla Inc',header=5)
df1.head(5)
# Out:
#                      Date                 Open    High     Low   Close  \
# 0 2024-07-01 16:00:00.288  1900-07-19 00:28:48  213.23  200.85  209.86
# 1 2024-07-02 16:00:00.288               218.89  231.30  218.06  231.26
# 2 2024-07-03 13:05:00.096               234.56  248.35  234.25  246.39
# 3 2024-07-05 16:00:00.288               249.81  252.37  242.46  251.52
# 4 2024-07-08 16:00:00.288               247.71  259.44  244.57  252.94
#
#       Volume
# 0  135691395
# 1  205047920
# 2  166561471
# 3  154501152
# 4  157219580

# %%
df1.shape
# Out:
# (263, 6)

# %% [markdown]
# + let us say that for whatever reason, the data you are processing does not have the date column
# + this is bad because to analyse a time-series dataset, you need those dates
# + the `date_range()` function will allow you to generate dates
# + another thing to note is that a time-series data may e missing some dates
# + the stock market prices for example does not have entries for weekends and say for example holidays probably because stocks did not trade on weekends
# + the `date_range()` func allows you to handle this

# %%
tsla=df1[['Open','High','Low','Close','Volume']].copy()
tsla.head(5)
# Out:
#                   Open    High     Low   Close     Volume
# 0  1900-07-19 00:28:48  213.23  200.85  209.86  135691395
# 1               218.89  231.30  218.06  231.26  205047920
# 2               234.56  248.35  234.25  246.39  166561471
# 3               249.81  252.37  242.46  251.52  154501152
# 4               247.71  259.44  244.57  252.94  157219580

# %%
tsla['Open']=pd.to_numeric(tsla['Open'], errors='coerce')
tsla.at[0,'Open']=tsla['Open'].mean()

# %%
tsla[:5]
# Out:
#          Open    High     Low   Close     Volume
# 0  296.670802  213.23  200.85  209.86  135691395
# 1  218.890000  231.30  218.06  231.26  205047920
# 2  234.560000  248.35  234.25  246.39  166561471
# 3  249.810000  252.37  242.46  251.52  154501152
# 4  247.710000  259.44  244.57  252.94  157219580

# %%
tsla.shape
# Out:
# (263, 5)

# %%
rng=pd.date_range(start='2024-07-01',periods=len(tsla),freq='B')
rng
# Out:
# DatetimeIndex(['2024-07-01', '2024-07-02', '2024-07-03', '2024-07-04',
#                '2024-07-05', '2024-07-08', '2024-07-09', '2024-07-10',
#                '2024-07-11', '2024-07-12',
#                ...
#                '2025-06-19', '2025-06-20', '2025-06-23', '2025-06-24',
#                '2025-06-25', '2025-06-26', '2025-06-27', '2025-06-30',
#                '2025-07-01', '2025-07-02'],
#               dtype='datetime64[ns]', length=263, freq='B')

# %%
tsla.set_index(rng, inplace=True)
tsla[:5]
# Out:
#                   Open    High     Low   Close     Volume
# 2024-07-01  296.670802  213.23  200.85  209.86  135691395
# 2024-07-02  218.890000  231.30  218.06  231.26  205047920
# 2024-07-03  234.560000  248.35  234.25  246.39  166561471
# 2024-07-04  249.810000  252.37  242.46  251.52  154501152
# 2024-07-05  247.710000  259.44  244.57  252.94  157219580

# %%
tsla.tail(5)
# Out:
#               Open    High     Low   Close    Volume
# 2025-06-26  317.73  322.60  312.67  316.90  78043430
# 2025-06-27  319.68  321.20  310.50  310.78  77556346
# 2025-06-30  312.80  323.50  312.62  321.67  97284786
# 2025-07-01  323.15  324.34  317.06  319.41  73922870
# 2025-07-02  321.66  330.90  321.42  329.65  94254993

# %%
tsla['Close'].plot()
# Out:
# <Axes: >

# %%
plt.plot(tsla['Close'],linestyle='-',linewidth=0.5,color='orangered')
plt.title('Tesla Stock Closing Prices')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.show()

# %%
tsla.loc['2024-07-01':'2024-07-10']['Close'].mean()
# Out:
# 244.82375

# %% [markdown]
# + for the missing stocks market prices data for dates that fall on weekends, we could assume that the prices on Friday is the same for Saturday and Sunday
# + to fill the missing data points, we could use the `asfreq()` function, it will allow us to regenerate a new DataFrame according to that frequency

# %%
tsla.asfreq('D', method='ffill').head(20)
# Out:
#                   Open    High     Low   Close     Volume
# 2024-07-01  296.670802  213.23  200.85  209.86  135691395
# 2024-07-02  218.890000  231.30  218.06  231.26  205047920
# 2024-07-03  234.560000  248.35  234.25  246.39  166561471
# 2024-07-04  249.810000  252.37  242.46  251.52  154501152
# 2024-07-05  247.710000  259.44  244.57  252.94  157219580
# 2024-07-06  247.710000  259.44  244.57  252.94  157219580
# 2024-07-07  247.710000  259.44  244.57  252.94  157219580
# 2024-07-08  251.000000  265.61  250.30  262.33  160742516
# 2024-07-09  262.800000  267.59  257.86  263.26  128519430
# 2024-07-10  263.300000  271.00  239.65  241.03  221707273
# 2024-07-11  235.800000  251.84  233.09  248.23  155955773
# 2024-07-12  255.970000  265.60  251.73  252.64  146912920
# 2024-07-13  255.970000  265.60  251.73  252.64  146912920
# 2024-07-14  255.970000  265.60  251.73  252.64  146912920
# 2024-07-15  255.310000  258.62  245.80  256.56  126332470
# 2024-07-16  252.730000  258.47  246.18  248.50  115584810
# 2024-07-17  251.090000  257.14  247.20  249.23  110869037
# 2024-07-18  247.790000  249.44  236.83  239.20   87403903
# 2024-07-19  244.210000  253.21  243.75  251.51  101225430
# 2024-07-20  244.210000  253.21  243.75  251.51  101225430

# %%
tsla.shape
# Out:
# (263, 5)

# %%
tsla.asfreq('W', method='ffill')
# Out:
#               Open    High     Low   Close     Volume
# 2024-07-07  247.71  259.44  244.57  252.94  157219580
# 2024-07-14  255.97  265.60  251.73  252.64  146912920
# 2024-07-21  244.21  253.21  243.75  251.51  101225430
# 2024-07-28  224.90  234.27  224.70  232.10  129201789
# 2024-08-04  185.22  203.88  182.00  198.88  100308836
# 2024-08-11  199.02  199.26  194.67  197.49   64044903
# 2024-08-18  217.07  222.98  214.09  222.72   76435222
# 2024-08-25  218.75  219.09  211.01  213.21   59301187
# 2024-09-01  215.26  219.90  209.64  210.60   76714222
# 2024-09-08  220.07  226.40  218.64  226.17   78891136
# 2024-09-15  229.45  234.57  226.55  227.87   66761636
# 2024-09-22  254.08  257.19  249.05  254.27   88490999
# 2024-09-29  262.67  263.98  248.53  258.02   87397613
# 2024-10-06  243.56  246.21  240.56  244.50   56303160
# 2024-10-13  220.01  224.26  217.12  219.57   62988787
# 2024-10-20  217.31  218.22  215.26  217.97   43268741
# 2024-10-27  264.51  264.98  255.51  259.52   80521751
# 2024-11-03  247.34  255.28  246.21  251.44   69282505
# 2024-11-10  342.74  345.84  323.31  328.49  155726016
# 2024-11-17  335.76  347.38  332.75  346.00   88852452
# 2024-11-24  341.00  346.96  335.66  338.23   62295857
# 2024-12-01  353.00  358.10  348.60  357.93   50810874
# 2024-12-08  409.70  424.88  402.38  424.77  104287559
# 2024-12-15  466.50  488.54  427.01  440.13  149340788
# 2024-12-22  465.16  465.33  451.02  454.13   76651210
# 2024-12-29  381.48  411.88  379.45  410.44   95423329
# 2025-01-05  383.21  403.79  380.07  403.31   67580494
# 2025-01-12  432.64  433.20  406.31  424.07   87320894
# 2025-01-19  396.91  400.59  386.50  398.09   48910676
# 2025-01-26  382.63  394.00  381.40  392.21   57072235
# 2025-02-02  345.80  349.37  325.10  328.50  118543400
# 2025-02-09  354.00  367.34  353.67  360.56   67094374
# 2025-02-16  303.71  309.00  288.04  290.80  100118276
# 2025-02-23  272.92  279.55  267.71  279.10   94042913
# 2025-03-02  247.22  251.84  241.10  248.09  142215681
# 2025-03-09  231.61  241.41  229.20  235.86  111993753
# 2025-03-16  282.66  284.90  266.51  272.06  156254441
# 2025-03-23  254.60  284.99  251.27  282.76  212787817
# 2025-03-30  224.69  274.69  223.88  272.20  219433373
# 2025-04-06  247.61  251.97  233.89  241.55  112378737
# 2025-04-13  250.50  259.54  249.20  259.51   94464195
# 2025-04-20  280.01  290.87  279.81  280.52   99658974
# 2025-04-27  279.63  289.80  279.41  284.82   97539448
# 2025-05-04  340.34  346.14  334.72  342.82   97882596
# 2025-05-11  344.43  347.35  332.20  334.62    5462213
# 2025-05-18  355.52  363.68  345.29  346.46  123474938
# 2025-05-25  298.83  305.50  291.14  295.14  164747685
# 2025-06-01  313.97  332.99  313.30  325.31  128964279
# 2025-06-08  327.54  357.54  327.48  348.68  190716815
# 2025-06-15  319.90  325.58  316.60  317.66   76695081
# 2025-06-22  297.00  304.05  294.35  297.81  103246742
# 2025-06-29  319.68  321.20  310.50  310.78   77556346

# %%
tsla.asfreq('h', method='ffill').head(10)
# Out:
#                            Open    High     Low   Close     Volume
# 2024-07-01 00:00:00  296.670802  213.23  200.85  209.86  135691395
# 2024-07-01 01:00:00  296.670802  213.23  200.85  209.86  135691395
# 2024-07-01 02:00:00  296.670802  213.23  200.85  209.86  135691395
# 2024-07-01 03:00:00  296.670802  213.23  200.85  209.86  135691395
# 2024-07-01 04:00:00  296.670802  213.23  200.85  209.86  135691395
# 2024-07-01 05:00:00  296.670802  213.23  200.85  209.86  135691395
# 2024-07-01 06:00:00  296.670802  213.23  200.85  209.86  135691395
# 2024-07-01 07:00:00  296.670802  213.23  200.85  209.86  135691395
# 2024-07-01 08:00:00  296.670802  213.23  200.85  209.86  135691395
# 2024-07-01 09:00:00  296.670802  213.23  200.85  209.86  135691395

# %%
ts=pd.Series(np.random.randint(1,10,len(rng)), index=rng)
ts.head(10)
# Out:
# 2024-07-01    1
# 2024-07-02    8
# 2024-07-03    2
# 2024-07-04    2
# 2024-07-05    3
# 2024-07-08    7
# 2024-07-09    9
# 2024-07-10    1
# 2024-07-11    1
# 2024-07-12    9
# Freq: B, dtype: int32

# %% [markdown]
# ##### Holidays
# + handling holidays in Pandas time-series analysis
# + creating a custom holiday calender and generate a date_time index out of it

# %%
from pandas.tseries.holiday import USFederalHolidayCalendar
from pandas.tseries.offsets import CustomBusinessDay

# %%
usbc = CustomBusinessDay(calendar=USFederalHolidayCalendar())
usbc

# %%
df_1=pd.read_excel('../datasets/stock market prices/Historical Stock Market Prices.xlsx','Apple Inc')
df_1[:5]
# Out:
#                      Date    Open    High     Low   Close    Volume
# 0 2024-07-01 16:00:00.288  212.09  217.51  211.92  216.75  60402929
# 1 2024-07-02 16:00:00.288  216.15  220.38  215.10  220.27  58046178
# 2 2024-07-03 13:05:00.096  220.00  221.55  219.03  221.55  37369801
# 3 2024-07-05 16:00:00.288  221.65  226.45  221.65  226.34  60412408
# 4 2024-07-08 16:00:00.288  227.09  227.85  223.25  227.82  59085861

# %%
aapl=df_1[['Open','High','Low','Close','Volume']].copy()
aapl.head(5)
# Out:
#      Open    High     Low   Close    Volume
# 0  212.09  217.51  211.92  216.75  60402929
# 1  216.15  220.38  215.10  220.27  58046178
# 2  220.00  221.55  219.03  221.55  37369801
# 3  221.65  226.45  221.65  226.34  60412408
# 4  227.09  227.85  223.25  227.82  59085861

# %%
rng1=pd.date_range(start='2024-07-01',periods=len(aapl),freq=usbc)

# %%
aapl.set_index(rng1,inplace=True)
aapl.head(5)
# Out:
#               Open    High     Low   Close    Volume
# 2024-07-01  212.09  217.51  211.92  216.75  60402929
# 2024-07-02  216.15  220.38  215.10  220.27  58046178
# 2024-07-03  220.00  221.55  219.03  221.55  37369801
# 2024-07-05  221.65  226.45  221.65  226.34  60412408
# 2024-07-08  227.09  227.85  223.25  227.82  59085861

# %% [markdown]
# #### custom calender

# %%
from pandas.tseries.holiday import AbstractHolidayCalendar, Holiday, nearest_workday

class MyBirthdayCalendar(AbstractHolidayCalendar):

    rules = [
        Holiday("Gichuki's Birthday", month=1, day=31, observance=nearest_workday),
        
    ]

my_birthday_calendar = CustomBusinessDay(calendar=MyBirthdayCalendar())
my_birthday_calendar

# %%
# Example usage of the custom calendar
pd.date_range(start='2025-01-20', end='2025-02-10', freq=my_birthday_calendar)
# Out:
# DatetimeIndex(['2025-01-20', '2025-01-21', '2025-01-22', '2025-01-23',
#                '2025-01-24', '2025-01-27', '2025-01-28', '2025-01-29',
#                '2025-01-30', '2025-02-03', '2025-02-04', '2025-02-05',
#                '2025-02-06', '2025-02-07', '2025-02-10'],
#               dtype='datetime64[ns]', freq='C')

# %% [markdown]
# + business day for Egypt are from Sun - Thur
# + make a custom business calender

# %%
bc_for_Egypt = CustomBusinessDay(weekmask='Sun Mon Tue Wed Thu',holidays=['2025-07-23', '2025-07-24'])  # Example holidays
pd.date_range(start='2025-07-18',end='2025-07-28',freq=bc_for_Egypt)
# Out:
# DatetimeIndex(['2025-07-20', '2025-07-21', '2025-07-22', '2025-07-27',
#                '2025-07-28'],
#               dtype='datetime64[ns]', freq='C')

# %% [markdown]
# #### period and periodindex
# + timestamp - specific instance of time
# + time span - time duration or time period

# %%
y=pd.Period('2025')
y
# Out:
# Period('2025', 'Y-DEC')

# %%
dir(y)
# Out:
# ['__add__',
#  '__array_priority__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__radd__',
#  '__reduce__',
#  '__reduce_cython__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rsub__',
#  '__setattr__',
#  '__setstate__',
#  '__setstate_cython__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__weakref__',
#  '_add_offset',
#  '_add_timedeltalike_scalar',
#  '_dtype',
#  '_from_ordinal',
#  '_maybe_convert_freq',
#  '_require_matching_freq',
#  'asfreq',
#  'day',
#  'day_of_week',
#  'day_of_year',
#  'dayofweek',
#  'dayofyear',
#  'days_in_month',
#  'daysinmonth',
#  'end_time',
#  'freq',
#  'freqstr',
#  'hour',
#  'is_leap_year',
#  'minute',
#  'month',
#  'now',
#  'ordinal',
#  'quarter',
#  'qyear',
#  'second',
#  'start_time',
#  'strftime',
#  'to_timestamp',
#  'week',
#  'weekday',
#  'weekofyear',
#  'year']

# %%
y.start_time
# Out:
# Timestamp('2025-01-01 00:00:00')

# %%
y.end_time
# Out:
# Timestamp('2025-12-31 23:59:59.999999999')

# %%
# monthly period
y_monthly = pd.Period('2025-01', freq='M')
y_monthly
# Out:
# Period('2025-01', 'M')

# %%
y_monthly.start_time
# Out:
# Timestamp('2025-01-01 00:00:00')

# %%
y_monthly.end_time
# Out:
# Timestamp('2025-01-31 23:59:59.999999999')

# %%
# daily period
y_daily = pd.Period('2025-01-01', freq='D')
y_daily
# Out:
# Period('2025-01-01', 'D')

# %%
y_daily.start_time
# Out:
# Timestamp('2025-01-01 00:00:00')

# %%
y_daily.end_time
# Out:
# Timestamp('2025-01-01 23:59:59.999999999')

# %%
# periodindex
pi = pd.period_range('2024','2025',freq='Q')
pi
# Out:
# PeriodIndex(['2024Q1', '2024Q2', '2024Q3', '2024Q4', '2025Q1'], dtype='period[Q-DEC]')

# %%
df2=pd.read_excel('c:/Users/user/Downloads/Historical Stock Market Prices.xlsx','NVDA',header=1)
df2[:5]
# Out:
#               Period Ending Apr '25Apr 27, 2025 Jan '25Jan 26, 2025  \
# 0                   Revenue              148515              130497
# 1      Revenue Growth (YoY)              0.8617               1.142
# 2           Cost of Revenue               44395               32639
# 3              Gross Profit              104120               97858
# 4  Selling, General & Admin                3755                3491
#
#   Jan '24Jan 28, 2024 Jan '23Jan 29, 2023 Jan '22Jan 30, 2022  \
# 0               60922               26974               26914
# 1              1.2586              0.0022               0.614
# 2               16621               11618                9439
# 3               44301               15356               17475
# 4                2654                2440                2166
#
#   Jan '21Jan 31, 2021 2016 - 2020
# 0               16675     Upgrade
# 1              0.5273     Upgrade
# 2                6118     Upgrade
# 3               10557     Upgrade
# 4                1912     Upgrade

# %%
df2.columns
# Out:
# Index(['Period Ending', 'Apr '25Apr 27, 2025', 'Jan '25Jan 26, 2025',
#        'Jan '24Jan 28, 2024', 'Jan '23Jan 29, 2023', 'Jan '22Jan 30, 2022',
#        'Jan '21Jan 31, 2021', '2016 - 2020'],
#       dtype='object')

# %%
df2.columns[0]
# Out:
# 'Period Ending'

# %% [markdown]
# + we have to rename the first column into a proper identifier for the metrics

# %%
df2.rename(columns={df2.columns[0]:'Metric'}, inplace=True)

# %%
df2.columns
# Out:
# Index(['Metric', 'Apr '25Apr 27, 2025', 'Jan '25Jan 26, 2025',
#        'Jan '24Jan 28, 2024', 'Jan '23Jan 29, 2023', 'Jan '22Jan 30, 2022',
#        'Jan '21Jan 31, 2021', '2016 - 2020'],
#       dtype='object')

# %% [markdown]
# + we have to delete column `'2016 - 2020'` which is an aggregate bucket, we may need to exclude it for year-over-year analysis

# %%
df2.drop(columns=['2016 - 2020'], inplace=True)
df2.columns
# Out:
# Index(['Metric', 'Apr '25Apr 27, 2025', 'Jan '25Jan 26, 2025',
#        'Jan '24Jan 28, 2024', 'Jan '23Jan 29, 2023', 'Jan '22Jan 30, 2022',
#        'Jan '21Jan 31, 2021'],
#       dtype='object')

# %%
df2[:5]
# Out:
#                      Metric Apr '25Apr 27, 2025 Jan '25Jan 26, 2025  \
# 0                   Revenue              148515              130497
# 1      Revenue Growth (YoY)              0.8617               1.142
# 2           Cost of Revenue               44395               32639
# 3              Gross Profit              104120               97858
# 4  Selling, General & Admin                3755                3491
#
#   Jan '24Jan 28, 2024 Jan '23Jan 29, 2023 Jan '22Jan 30, 2022  \
# 0               60922               26974               26914
# 1              1.2586              0.0022               0.614
# 2               16621               11618                9439
# 3               44301               15356               17475
# 4                2654                2440                2166
#
#   Jan '21Jan 31, 2021
# 0               16675
# 1              0.5273
# 2                6118
# 3               10557
# 4                1912

# %% [markdown]
# ### 📊 Data Dictionary: Nvidia Financial Report
#
# This dataset contains key financial metrics for Nvidia Corporation across multiple fiscal years. The data is structured with **rows representing financial line items** (e.g., Revenue, Gross Profit) and **columns representing time periods**. Below is an explanation of each column:
#
# - **Fiscal Year**: The name of the financial metric or KPI (e.g., Revenue, Net Income, etc.).
# - **TTM (Trailing Twelve Months)**: Represents cumulative financial performance for the most recent 12-month period leading up to the report (not necessarily aligned with a fiscal year). Useful for evaluating up-to-date performance.
# - **FY 2025**: Projected or actual financial data for Nvidia’s Fiscal Year 2025. This fiscal year **ends in Jan 2025**, meaning it covers **February 2024 to January 2025**.
# - **FY 2024**: Actual financials for Fiscal Year 2024 (Feb 2023 – Jan 2024).
# - **FY 2023**: Actual financials for Fiscal Year 2023 (Feb 2022 – Jan 2023).
# - **FY 2022**: Actual financials for Fiscal Year 2022 (Feb 2021 – Jan 2022).
# - **FY 2021**: Actual financials for Fiscal Year 2021 (Feb 2020 – Jan 2021).
#
# > 🧠 **Note**: Nvidia's fiscal years do **not** align with calendar years. Each FY is labeled by the **year in which it ends** (e.g., FY 2024 ends in January 2024, but starts in February 2023).
#
# The actual period end dates (e.g., `Jan 28, 2024`) are shown in the first row of the dataset under each FY column for reference.
#
# ---

# %% [markdown]
# + drop the TTM column that is not needed for year-over-year analysis - the column name is actually `'Apr '25Apr 27, 2025'`
# + it gives the freshest view of performance across the most recent 12 months, without waiting for the fiscal year to close

# %%
df2["Apr '25Apr 27, 2025"][:2]
# Out:
# 0    148515
# 1    0.8617
# Name: Apr '25Apr 27, 2025, dtype: object

# %%
df2.drop(columns=["Apr '25Apr 27, 2025"], inplace=True)
df2.columns
# Out:
# Index(['Metric', 'Jan '25Jan 26, 2025', 'Jan '24Jan 28, 2024',
#        'Jan '23Jan 29, 2023', 'Jan '22Jan 30, 2022', 'Jan '21Jan 31, 2021'],
#       dtype='object')

# %%
fy2025=pd.Interval(left=pd.to_datetime('2024-01-29'), right=pd.to_datetime('2025-01-26'), closed='right')
fy2025
# Out:
# Interval(2024-01-29 00:00:00, 2025-01-26 00:00:00, closed='right')

# %%
fy2024=pd.Interval(left=pd.to_datetime('2023-01-30'), right=pd.to_datetime('2024-01-28'), closed='right')
fy2024
# Out:
# Interval(2023-01-30 00:00:00, 2024-01-28 00:00:00, closed='right')

# %%
fy2023=pd.Interval(left=pd.to_datetime('2022-01-31'), right=pd.to_datetime('2023-01-29'), closed='right')
fy2023
# Out:
# Interval(2022-01-31 00:00:00, 2023-01-29 00:00:00, closed='right')

# %%
fy2022=pd.Interval(left=pd.to_datetime('2021-01-31'), right=pd.to_datetime('2022-01-30'), closed='right')
fy2022
# Out:
# Interval(2021-01-31 00:00:00, 2022-01-30 00:00:00, closed='right')

# %%
fy2021=pd.Interval(left=pd.to_datetime('2020-02-01'), right=pd.to_datetime('2021-01-31'), closed='right')
fy2021
# Out:
# Interval(2020-02-01 00:00:00, 2021-01-31 00:00:00, closed='right')

# %%
df2.set_index('Metric', inplace=True)
df2[:5]
# Out:
#                          Jan '25Jan 26, 2025 Jan '24Jan 28, 2024  \
# Metric
# Revenue                               130497               60922
# Revenue Growth (YoY)                   1.142              1.2586
# Cost of Revenue                        32639               16621
# Gross Profit                           97858               44301
# Selling, General & Admin                3491                2654
#
#                          Jan '23Jan 29, 2023 Jan '22Jan 30, 2022  \
# Metric
# Revenue                                26974               26914
# Revenue Growth (YoY)                  0.0022               0.614
# Cost of Revenue                        11618                9439
# Gross Profit                           15356               17475
# Selling, General & Admin                2440                2166
#
#                          Jan '21Jan 31, 2021
# Metric
# Revenue                                16675
# Revenue Growth (YoY)                  0.5273
# Cost of Revenue                         6118
# Gross Profit                           10557
# Selling, General & Admin                1912

# %%
df2.columns
# Out:
# Index(['Jan '25Jan 26, 2025', 'Jan '24Jan 28, 2024', 'Jan '23Jan 29, 2023',
#        'Jan '22Jan 30, 2022', 'Jan '21Jan 31, 2021'],
#       dtype='object')

# %%
df2.columns[0]
# Out:
# "Jan '25Jan 26, 2025"

# %%
df2.rename(columns={df2.columns[0]:'FY2025'}, inplace=True)

# %%
df2.rename(columns={df2.columns[1]:'FY2024'}, inplace=True)

# %%
df2.rename(columns={df2.columns[2]:'FY2023'}, inplace=True)

# %%
df2.rename(columns={df2.columns[3]:'FY2022'}, inplace=True)

# %%
df2.rename(columns={df2.columns[4]:'FY2021'}, inplace=True)

# %%
df2[:5]
# Out:
#                           FY2025  FY2024  FY2023 FY2022  FY2021
# Metric
# Revenue                   130497   60922   26974  26914   16675
# Revenue Growth (YoY)       1.142  1.2586  0.0022  0.614  0.5273
# Cost of Revenue            32639   16621   11618   9439    6118
# Gross Profit               97858   44301   15356  17475   10557
# Selling, General & Admin    3491    2654    2440   2166    1912

# %%
df3=df2.T
df3[:5]
# Out:
# Metric Revenue Revenue Growth (YoY) Cost of Revenue Gross Profit  \
# FY2025  130497                1.142           32639        97858
# FY2024   60922               1.2586           16621        44301
# FY2023   26974               0.0022           11618        15356
# FY2022   26914                0.614            9439        17475
# FY2021   16675               0.5273            6118        10557
#
# Metric Selling, General & Admin Research & Development Operating Expenses  \
# FY2025                     3491                  12914              16405
# FY2024                     2654                   8675              11329
# FY2023                     2440                   7339               9779
# FY2022                     2166                   5268               7434
# FY2021                     1912                   3924               5836
#
# Metric Operating Income Interest Expense Interest & Investment Income  ...  \
# FY2025            81453             -247                         1786  ...
# FY2024            32972             -257                          866  ...
# FY2023             5577             -262                          267  ...
# FY2022            10041             -236                           29  ...
# FY2021             4721             -184                           57  ...
#
# Metric Gross Margin Operating Margin Profit Margin Free Cash Flow Margin  \
# FY2025       0.7499           0.6242        0.5585                0.4663
# FY2024       0.7272           0.5412        0.4885                0.4435
# FY2023       0.5693           0.2067        0.1619                0.1412
# FY2022       0.6493           0.3731        0.3623                0.3021
# FY2021       0.6331           0.2831        0.2598                0.2815
#
# Metric EBITDA EBITDA Margin D&A For EBITDA   EBIT EBIT Margin  \
# FY2025  83317        0.6385           1864  81453      0.6242
# FY2024  34480         0.566           1508  32972      0.5412
# FY2023   7121         0.264           1544   5577      0.2067
# FY2022  11215        0.4167           1174  10041      0.3731
# FY2021   5819         0.349           1098   4721      0.2831
#
# Metric Effective Tax Rate
# FY2025             0.1326
# FY2024               0.12
# FY2023                  -
# FY2022              0.019
# FY2021             0.0175
#
# [5 rows x 39 columns]

# %%
# map fiscal years to start and end dates
fy_dates = {
    'FY2025': {'start': pd.to_datetime('2024-01-29'), 'end': pd.to_datetime('2025-01-26')},
    'FY2024': {'start': pd.to_datetime('2023-01-30'), 'end': pd.to_datetime('2024-01-28')},
    'FY2023': {'start': pd.to_datetime('2022-01-31'), 'end': pd.to_datetime('2023-01-29')},
    'FY2022': {'start': pd.to_datetime('2021-01-31'), 'end': pd.to_datetime('2022-01-30')},
    'FY2021': {'start': pd.to_datetime('2020-02-01'), 'end': pd.to_datetime('2021-01-31')}
}

# %%
# create the new columns using the DataFrame index
df3['Start date'] = df3.index.map(lambda fy: fy_dates[fy]['start'])

# %%
df3['End date'] = df3.index.map(lambda fy: fy_dates[fy]['end'])

# %%
df3.index
# Out:
# Index(['FY2025', 'FY2024', 'FY2023', 'FY2022', 'FY2021'], dtype='object')

# %%
df3.columns
# Out:
# Index(['Revenue', 'Revenue Growth (YoY)', 'Cost of Revenue', 'Gross Profit',
#        'Selling, General & Admin', 'Research & Development',
#        'Operating Expenses', 'Operating Income', 'Interest Expense',
#        'Interest & Investment Income', 'Other Non Operating Income (Expenses)',
#        'EBT Excluding Unusual Items', 'Merger & Restructuring Charges',
#        'Gain (Loss) on Sale of Investments', 'Pretax Income',
#        'Income Tax Expense', 'Net Income', 'Net Income to Common',
#        'Net Income Growth', 'Shares Outstanding (Basic)',
#        'Shares Outstanding (Diluted)', 'Shares Change (YoY)', 'EPS (Basic)',
#        'EPS (Diluted)', 'EPS Growth', 'Free Cash Flow',
#        'Free Cash Flow Per Share', 'Dividend Per Share', 'Dividend Growth',
#        'Gross Margin', 'Operating Margin', 'Profit Margin',
#        'Free Cash Flow Margin', 'EBITDA', 'EBITDA Margin', 'D&A For EBITDA',
#        'EBIT', 'EBIT Margin', 'Effective Tax Rate', 'Start date', 'End date'],
#       dtype='object', name='Metric')

# %%
df3['Revenue'].head(5)
# Out:
# FY2025    130497
# FY2024     60922
# FY2023     26974
# FY2022     26914
# FY2021     16675
# Name: Revenue, dtype: object

# %%
nvda=df3[['Start date','End date','Revenue','Net Income','Operating Income','Free Cash Flow','EPS (Diluted)']].copy()
nvda[:5]
# Out:
# Metric Start date   End date Revenue Net Income Operating Income  \
# FY2025 2024-01-29 2025-01-26  130497      72880            81453
# FY2024 2023-01-30 2024-01-28   60922      29760            32972
# FY2023 2022-01-31 2023-01-29   26974       4368             5577
# FY2022 2021-01-31 2022-01-30   26914       9752            10041
# FY2021 2020-02-01 2021-01-31   16675       4332             4721
#
# Metric Free Cash Flow EPS (Diluted)
# FY2025          60853          2.94
# FY2024          27021          1.19
# FY2023           3808          0.17
# FY2022           8132          0.39
# FY2021           4694          0.17

# %%
nvda.index
# Out:
# Index(['FY2025', 'FY2024', 'FY2023', 'FY2022', 'FY2021'], dtype='object')

# %%
nvda.columns
# Out:
# Index(['Start date', 'End date', 'Revenue', 'Net Income', 'Operating Income',
#        'Free Cash Flow', 'EPS (Diluted)'],
#       dtype='object', name='Metric')

# %%
import pandas as pd
import numpy as np
dates = pd.date_range(start='2025-01-01', end='2025-01-31', freq='D').to_list()
numbers = np.random.randint(1, 100, len(dates))
df7 = pd.DataFrame({'Date': dates, 'Price': numbers})
df7[:5]
# Out:
#         Date  Price
# 0 2025-01-01      1
# 1 2025-01-02     62
# 2 2025-01-03     76
# 3 2025-01-04     73
# 4 2025-01-05      1

# %%
import matplotlib.pyplot as plt
df7.plot(kind='line', x='Date', y='Price', figsize=(10, 6), color='orangered')
plt.title('Daily Stock Prices in 2025')
plt.xlabel('Date') 
plt.ylabel('Price')
plt.show()

# %%
df7['Moving Avg'] = df7['Price'].rolling(window=7).mean()

# %%
df7.head(20)
# Out:
#          Date  Price  Moving Avg
# 0  2025-01-01      1         NaN
# 1  2025-01-02     62         NaN
# 2  2025-01-03     76         NaN
# 3  2025-01-04     73         NaN
# 4  2025-01-05      1         NaN
# 5  2025-01-06     18         NaN
# 6  2025-01-07     98   47.000000
# 7  2025-01-08      8   48.000000
# 8  2025-01-09     29   43.285714
# 9  2025-01-10     38   37.857143
# 10 2025-01-11     41   33.285714
# 11 2025-01-12     95   46.714286
# 12 2025-01-13     26   47.857143
# 13 2025-01-14     73   44.285714
# 14 2025-01-15     67   52.714286
# 15 2025-01-16     88   61.142857
# 16 2025-01-17     48   62.571429
# 17 2025-01-18     48   63.571429
# 18 2025-01-19     65   59.285714
# 19 2025-01-20     95   69.142857

# %%
df7.plot(kind='line', x='Date', y=['Price', 'Moving Avg'], figsize=(10, 6))
# Out:
# <Axes: xlabel='Date'>

# %%
df7['Rolling Ave Center'] = df7['Price'].rolling(window=5, center=True).mean()

# %%
df7.head(20)
# Out:
#          Date  Price  Moving Avg  Rolling Ave Center
# 0  2025-01-01      1         NaN                 NaN
# 1  2025-01-02     62         NaN                 NaN
# 2  2025-01-03     76         NaN                42.6
# 3  2025-01-04     73         NaN                46.0
# 4  2025-01-05      1         NaN                53.2
# 5  2025-01-06     18         NaN                39.6
# 6  2025-01-07     98   47.000000                30.8
# 7  2025-01-08      8   48.000000                38.2
# 8  2025-01-09     29   43.285714                42.8
# 9  2025-01-10     38   37.857143                42.2
# 10 2025-01-11     41   33.285714                45.8
# 11 2025-01-12     95   46.714286                54.6
# 12 2025-01-13     26   47.857143                60.4
# 13 2025-01-14     73   44.285714                69.8
# 14 2025-01-15     67   52.714286                60.4
# 15 2025-01-16     88   61.142857                64.8
# 16 2025-01-17     48   62.571429                63.2
# 17 2025-01-18     48   63.571429                68.8
# 18 2025-01-19     65   59.285714                69.2
# 19 2025-01-20     95   69.142857                75.0

# %%
df7.iloc[5:7, 1] = np.NaN

# %%
df7.head(15)
# Out:
#          Date  Price  Moving Avg  Rolling Ave Center
# 0  2025-01-01    1.0         NaN                 NaN
# 1  2025-01-02   62.0         NaN                 NaN
# 2  2025-01-03   76.0         NaN                42.6
# 3  2025-01-04   73.0         NaN                46.0
# 4  2025-01-05    1.0         NaN                53.2
# 5  2025-01-06    NaN         NaN                39.6
# 6  2025-01-07    NaN   47.000000                30.8
# 7  2025-01-08    8.0   48.000000                38.2
# 8  2025-01-09   29.0   43.285714                42.8
# 9  2025-01-10   38.0   37.857143                42.2
# 10 2025-01-11   41.0   33.285714                45.8
# 11 2025-01-12   95.0   46.714286                54.6
# 12 2025-01-13   26.0   47.857143                60.4
# 13 2025-01-14   73.0   44.285714                69.8
# 14 2025-01-15   67.0   52.714286                60.4

# %%
df7['Min Periods'] = df7['Price'].rolling(window=5, min_periods=5).mean()

# %%
df7.head(15)
# Out:
#          Date  Price  Moving Avg  Rolling Ave Center  Min Periods
# 0  2025-01-01    1.0         NaN                 NaN          NaN
# 1  2025-01-02   62.0         NaN                 NaN          NaN
# 2  2025-01-03   76.0         NaN                42.6          NaN
# 3  2025-01-04   73.0         NaN                46.0          NaN
# 4  2025-01-05    1.0         NaN                53.2         42.6
# 5  2025-01-06    NaN         NaN                39.6          NaN
# 6  2025-01-07    NaN   47.000000                30.8          NaN
# 7  2025-01-08    8.0   48.000000                38.2          NaN
# 8  2025-01-09   29.0   43.285714                42.8          NaN
# 9  2025-01-10   38.0   37.857143                42.2          NaN
# 10 2025-01-11   41.0   33.285714                45.8          NaN
# 11 2025-01-12   95.0   46.714286                54.6         42.2
# 12 2025-01-13   26.0   47.857143                60.4         45.8
# 13 2025-01-14   73.0   44.285714                69.8         54.6
# 14 2025-01-15   67.0   52.714286                60.4         60.4
