# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
unames = ['user_id', 'gender', 'age', 'occupation', 'zip']
users = pd.read_table('../datasets/ml-1m/users.dat', sep='::', header=None, names=unames, engine='python')

# %%
rnames = ['user_id', 'movie_id', 'rating', 'timestamp']
ratings = pd.read_table('../datasets/ml-1m/ratings.dat', sep='::', header=None, names=rnames, engine='python')

# %%
mnames = ['movie_id', 'title', 'genres']
movies = pd.read_table('../datasets/ml-1m/movies.dat', sep='::', header=None, names=mnames, engine='python')

# %%
users.head(10)
# Out:
#    user_id gender  age  occupation    zip
# 0        1      F    1          10  48067
# 1        2      M   56          16  70072
# 2        3      M   25          15  55117
# 3        4      M   45           7  02460
# 4        5      M   25          20  55455
# 5        6      F   50           9  55117
# 6        7      M   35           1  06810
# 7        8      M   25          12  11413
# 8        9      M   25          17  61614
# 9       10      F   35           1  95370

# %%
users.shape
# Out:
# (6040, 5)

# %%
users.describe()
# Out:
#            user_id          age   occupation
# count  6040.000000  6040.000000  6040.000000
# mean   3020.500000    30.639238     8.146854
# std    1743.742145    12.895962     6.329511
# min       1.000000     1.000000     0.000000
# 25%    1510.750000    25.000000     3.000000
# 50%    3020.500000    25.000000     7.000000
# 75%    4530.250000    35.000000    14.000000
# max    6040.000000    56.000000    20.000000

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6040 entries, 0 to 6039
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     6040 non-null   int64
#  1   gender      6040 non-null   object
#  2   age         6040 non-null   int64
#  3   occupation  6040 non-null   int64
#  4   zip         6040 non-null   object
# dtypes: int64(3), object(2)
# memory usage: 236.1+ KB

# %%
ratings.head(10)
# Out:
#    user_id  movie_id  rating  timestamp
# 0        1      1193       5  978300760
# 1        1       661       3  978302109
# 2        1       914       3  978301968
# 3        1      3408       4  978300275
# 4        1      2355       5  978824291
# 5        1      1197       3  978302268
# 6        1      1287       5  978302039
# 7        1      2804       5  978300719
# 8        1       594       4  978302268
# 9        1       919       4  978301368

# %%
ratings.shape
# Out:
# (1000209, 4)

# %%
ratings[10:]
# Out:
#          user_id  movie_id  rating  timestamp
# 10             1       595       5  978824268
# 11             1       938       4  978301752
# 12             1      2398       4  978302281
# 13             1      2918       4  978302124
# 14             1      1035       5  978301753
# ...          ...       ...     ...        ...
# 1000204     6040      1091       1  956716541
# 1000205     6040      1094       5  956704887
# 1000206     6040       562       5  956704746
# 1000207     6040      1096       4  956715648
# 1000208     6040      1097       4  956715569
#
# [1000199 rows x 4 columns]

# %%
ratings[:10]
# Out:
#    user_id  movie_id  rating  timestamp
# 0        1      1193       5  978300760
# 1        1       661       3  978302109
# 2        1       914       3  978301968
# 3        1      3408       4  978300275
# 4        1      2355       5  978824291
# 5        1      1197       3  978302268
# 6        1      1287       5  978302039
# 7        1      2804       5  978300719
# 8        1       594       4  978302268
# 9        1       919       4  978301368

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000209 entries, 0 to 1000208
# Data columns (total 4 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   user_id    1000209 non-null  int64
#  1   movie_id   1000209 non-null  int64
#  2   rating     1000209 non-null  int64
#  3   timestamp  1000209 non-null  int64
# dtypes: int64(4)
# memory usage: 30.5 MB

# %%
ratings.describe()
# Out:
#             user_id      movie_id        rating     timestamp
# count  1.000209e+06  1.000209e+06  1.000209e+06  1.000209e+06
# mean   3.024512e+03  1.865540e+03  3.581564e+00  9.722437e+08
# std    1.728413e+03  1.096041e+03  1.117102e+00  1.215256e+07
# min    1.000000e+00  1.000000e+00  1.000000e+00  9.567039e+08
# 25%    1.506000e+03  1.030000e+03  3.000000e+00  9.653026e+08
# 50%    3.070000e+03  1.835000e+03  4.000000e+00  9.730180e+08
# 75%    4.476000e+03  2.770000e+03  4.000000e+00  9.752209e+08
# max    6.040000e+03  3.952000e+03  5.000000e+00  1.046455e+09

# %%
movies.head(10)
# Out:
#    movie_id                               title                        genres
# 0         1                    Toy Story (1995)   Animation|Children's|Comedy
# 1         2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2         3             Grumpier Old Men (1995)                Comedy|Romance
# 3         4            Waiting to Exhale (1995)                  Comedy|Drama
# 4         5  Father of the Bride Part II (1995)                        Comedy
# 5         6                         Heat (1995)         Action|Crime|Thriller
# 6         7                      Sabrina (1995)                Comedy|Romance
# 7         8                 Tom and Huck (1995)          Adventure|Children's
# 8         9                 Sudden Death (1995)                        Action
# 9        10                    GoldenEye (1995)     Action|Adventure|Thriller

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3883 entries, 0 to 3882
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   movie_id  3883 non-null   int64
#  1   title     3883 non-null   object
#  2   genres    3883 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 91.1+ KB

# %% [markdown]
# ##### computing mean ratings for a particular movie by sex and age
#
# #### Goal
# + create one unified table that includes,
#   + ratings - user ratings of the movies
#   + users - information aout the user
#   + movies - information about the movie
# + each row will have one rating, who gave it, which movie it was for, and details about the movie and the name
# + we want to get a full picture of every rating, who rated what movie, what they thought, and who they are

# %%
# using pandas merge fn to merge  ratings with users then merging with the movies data
data = pd.merge(pd.merge(ratings, users), movies)
data.head()
# Out:
#    user_id  movie_id  rating  timestamp gender  age  occupation    zip  \
# 0        1      1193       5  978300760      F    1          10  48067
# 1        1       661       3  978302109      F    1          10  48067
# 2        1       914       3  978301968      F    1          10  48067
# 3        1      3408       4  978300275      F    1          10  48067
# 4        1      2355       5  978824291      F    1          10  48067
#
#                                     title                        genres
# 0  One Flew Over the Cuckoo's Nest (1975)                         Drama
# 1        James and the Giant Peach (1996)  Animation|Children's|Musical
# 2                     My Fair Lady (1964)               Musical|Romance
# 3                  Erin Brockovich (2000)                         Drama
# 4                    Bug's Life, A (1998)   Animation|Children's|Comedy

# %% [markdown]
# ```
# data = pd.merge(pd.merge(ratings, users), movies)
# ```
#
# `pd.merge(ratings, users)` - this merges the ratings dataframe with users on a common columns, ***user_id***
#
# `pd.merge(..., movies)` - this merges the result of the first merge with the movies dataframe on the ***movie_id*** column which is common to both dataframes

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000209 entries, 0 to 1000208
# Data columns (total 10 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   user_id     1000209 non-null  int64
#  1   movie_id    1000209 non-null  int64
#  2   rating      1000209 non-null  int64
#  3   timestamp   1000209 non-null  int64
#  4   gender      1000209 non-null  object
#  5   age         1000209 non-null  int64
#  6   occupation  1000209 non-null  int64
#  7   zip         1000209 non-null  object
#  8   title       1000209 non-null  object
#  9   genres      1000209 non-null  object
# dtypes: int64(6), object(4)
# memory usage: 76.3+ MB

# %%
data.shape
# Out:
# (1000209, 10)

# %%
data.iloc[0]
# Out:
# user_id                                            1
# movie_id                                        1193
# rating                                             5
# timestamp                                  978300760
# gender                                             F
# age                                                1
# occupation                                        10
# zip                                            48067
# title         One Flew Over the Cuckoo's Nest (1975)
# genres                                         Drama
# Name: 0, dtype: object

# %%
mean_ratings = data.pivot_table('rating', index='title', columns='gender', aggfunc='mean')
mean_ratings[:5]
# Out:
# gender                                F         M
# title
# $1,000,000 Duck (1971)         3.375000  2.761905
# 'Night Mother (1986)           3.388889  3.352941
# 'Til There Was You (1997)      2.675676  2.733333
# 'burbs, The (1989)             2.793478  2.962085
# ...And Justice for All (1979)  3.828571  3.689024

# %%
mean_rating_s = pd.pivot_table(data, values='rating', index='title', columns='gender', aggfunc='mean')
mean_rating_s.head(10)
# Out:
# gender                                    F         M
# title
# $1,000,000 Duck (1971)             3.375000  2.761905
# 'Night Mother (1986)               3.388889  3.352941
# 'Til There Was You (1997)          2.675676  2.733333
# 'burbs, The (1989)                 2.793478  2.962085
# ...And Justice for All (1979)      3.828571  3.689024
# 1-900 (1994)                       2.000000  3.000000
# 10 Things I Hate About You (1999)  3.646552  3.311966
# 101 Dalmatians (1961)              3.791444  3.500000
# 101 Dalmatians (1996)              3.240000  2.911215
# 12 Angry Men (1957)                4.184397  4.328421

# %% [markdown]
# #### filter down to movies that received at least 250 ratings
# + this is done by using the pandas `groupby()` function
# + we group the data by title and use `size()` function to get a ***Series*** of group sizes for each title
# + `SeriesGroupBy.size()` - Compute group sizes

# %%
ratings_by_title = data.groupby('title').size()

# %%
ratings_by_title.head(10)
# Out:
# title
# $1,000,000 Duck (1971)                37
# 'Night Mother (1986)                  70
# 'Til There Was You (1997)             52
# 'burbs, The (1989)                   303
# ...And Justice for All (1979)        199
# 1-900 (1994)                           2
# 10 Things I Hate About You (1999)    700
# 101 Dalmatians (1961)                565
# 101 Dalmatians (1996)                364
# 12 Angry Men (1957)                  616
# dtype: int64

# %%
ratings_by_title.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 3706 entries, $1,000,000 Duck (1971) to eXistenZ (1999)
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 3706 non-null   int64
# dtypes: int64(1)
# memory usage: 186.9+ KB

# %% [markdown]
# #### `rating_by_title` - this is a Pandas Series where the index is the movie title and the value is a count of ratings per title

# %%
active_titles=ratings_by_title.index[ratings_by_title >= 250]
active_titles
# Out:
# Index([''burbs, The (1989)', '10 Things I Hate About You (1999)',
#        '101 Dalmatians (1961)', '101 Dalmatians (1996)', '12 Angry Men (1957)',
#        '13th Warrior, The (1999)', '2 Days in the Valley (1996)',
#        '20,000 Leagues Under the Sea (1954)', '2001: A Space Odyssey (1968)',
#        '2010 (1984)',
#        ...
#        'X-Men (2000)', 'Year of Living Dangerously (1982)',
#        'Yellow Submarine (1968)', 'You've Got Mail (1998)',
#        'Young Frankenstein (1974)', 'Young Guns (1988)',
#        'Young Guns II (1990)', 'Young Sherlock Holmes (1985)',
#        'Zero Effect (1998)', 'eXistenZ (1999)'],
#       dtype='object', name='title', length=1216)

# %% [markdown]
# ##### `ratings_by_title >= 250` - this creates a boolean Series to check the popularity of the movies, we basically want to answer a question of whether the movie title got at least 250 ratings
# ##### `ratings_by_title.index[...]` - this does boolean indexing on the Series index itself and returns an Index object which is a list of movies that passed the `>= 250` filter
# ##### `active_titles` - this is a list like object that has popular movie titles that have ratings above 250
# ##### the object can now be used to slice down the full ratings table to those with enough data to be statistically interesting

# %%
mean_ratings=mean_ratings.loc[active_titles]
mean_ratings
# Out:
# gender                                    F         M
# title
# 'burbs, The (1989)                 2.793478  2.962085
# 10 Things I Hate About You (1999)  3.646552  3.311966
# 101 Dalmatians (1961)              3.791444  3.500000
# 101 Dalmatians (1996)              3.240000  2.911215
# 12 Angry Men (1957)                4.184397  4.328421
# ...                                     ...       ...
# Young Guns (1988)                  3.371795  3.425620
# Young Guns II (1990)               2.934783  2.904025
# Young Sherlock Holmes (1985)       3.514706  3.363344
# Zero Effect (1998)                 3.864407  3.723140
# eXistenZ (1999)                    3.098592  3.289086
#
# [1216 rows x 2 columns]

# %% [markdown]
# + we filter the `mean_ratings` DataFrame to show the titles that are popular
# + now we have a clean, filtered table of movies that matter in the analysis

# %%
top_female_ratings=mean_ratings.sort_values(by='F', ascending=False)
top_female_ratings[:10]
# Out:
# gender                                                     F         M
# title
# Close Shave, A (1995)                               4.644444  4.473795
# Wrong Trousers, The (1993)                          4.588235  4.478261
# Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)       4.572650  4.464589
# Wallace & Gromit: The Best of Aardman Animation...  4.563107  4.385075
# Schindler's List (1993)                             4.562602  4.491415
# Shawshank Redemption, The (1994)                    4.539075  4.560625
# Grand Day Out, A (1992)                             4.537879  4.293255
# To Kill a Mockingbird (1962)                        4.536667  4.372611
# Creature Comforts (1990)                            4.513889  4.272277
# Usual Suspects, The (1995)                          4.513317  4.518248

# %% [markdown]
# + we sort the data frame by the female average rating highest first
# + the results of the line of code returns a data frame where women gave the highest ratings

# %% [markdown]
# ##### measuring rating disagreement - the gender wars edition
# + the goal is to find the movies that are most divisive between male and female viewers

# %%
mean_ratings['diff']=mean_ratings['M']-mean_ratings['F']
mean_ratings[:5]
# Out:
# gender                                    F         M      diff
# title
# 'burbs, The (1989)                 2.793478  2.962085  0.168607
# 10 Things I Hate About You (1999)  3.646552  3.311966 -0.334586
# 101 Dalmatians (1961)              3.791444  3.500000 -0.291444
# 101 Dalmatians (1996)              3.240000  2.911215 -0.328785
# 12 Angry Men (1957)                4.184397  4.328421  0.144024

# %% [markdown]
# + we want to sort by the difference so that we know the movies with the greatest rating difference
# + that will tell us which movies were preferred by which gender
# + positive difference means men rated it higher
# + negative difference means women rated it higher

# %%
sorted_by_diff=mean_ratings.sort_values(by='diff')
sorted_by_diff[:15]
# Out:
# gender                                        F         M      diff
# title
# Dirty Dancing (1987)                   3.790378  2.959596 -0.830782
# Jumpin' Jack Flash (1986)              3.254717  2.578358 -0.676359
# Grease (1978)                          3.975265  3.367041 -0.608224
# Little Women (1994)                    3.870588  3.321739 -0.548849
# Steel Magnolias (1989)                 3.901734  3.365957 -0.535777
# Anastasia (1997)                       3.800000  3.281609 -0.518391
# Rocky Horror Picture Show, The (1975)  3.673016  3.160131 -0.512885
# Color Purple, The (1985)               4.158192  3.659341 -0.498851
# Age of Innocence, The (1993)           3.827068  3.339506 -0.487561
# Free Willy (1993)                      2.921348  2.438776 -0.482573
# French Kiss (1995)                     3.535714  3.056962 -0.478752
# Little Shop of Horrors, The (1960)     3.650000  3.179688 -0.470312
# Guys and Dolls (1955)                  4.051724  3.583333 -0.468391
# ...

# %%
sorted_by_diff.tail(15)
# Out:
# gender                                         F         M      diff
# title
# Barb Wire (1996)                        1.585366  2.100386  0.515020
# Fright Night (1985)                     2.973684  3.500000  0.526316
# Exorcist, The (1973)                    3.537634  4.067239  0.529605
# Animal House (1978)                     3.628906  4.167192  0.538286
# Porky's (1981)                          2.296875  2.836364  0.539489
# For a Few Dollars More (1965)           3.409091  3.953795  0.544704
# Caddyshack (1980)                       3.396135  3.969737  0.573602
# Rocky III (1982)                        2.361702  2.943503  0.581801
# Hidden, The (1987)                      3.137931  3.745098  0.607167
# Evil Dead II (Dead By Dawn) (1987)      3.297297  3.909283  0.611985
# Cable Guy, The (1996)                   2.250000  2.863787  0.613787
# Longest Day, The (1962)                 3.411765  4.031447  0.619682
# ...

# %% [markdown]
# ##### movies preferred by men that women didn't rate as high

# %%
sorted_by_diff.sort_values(by='diff', ascending=False)[:15]
# Out:
# gender                                         F         M      diff
# title
# Good, The Bad and The Ugly, The (1966)  3.494949  4.221300  0.726351
# Kentucky Fried Movie, The (1977)        2.878788  3.555147  0.676359
# Dumb & Dumber (1994)                    2.697987  3.336595  0.638608
# Longest Day, The (1962)                 3.411765  4.031447  0.619682
# Cable Guy, The (1996)                   2.250000  2.863787  0.613787
# Evil Dead II (Dead By Dawn) (1987)      3.297297  3.909283  0.611985
# Hidden, The (1987)                      3.137931  3.745098  0.607167
# Rocky III (1982)                        2.361702  2.943503  0.581801
# Caddyshack (1980)                       3.396135  3.969737  0.573602
# For a Few Dollars More (1965)           3.409091  3.953795  0.544704
# Porky's (1981)                          2.296875  2.836364  0.539489
# Animal House (1978)                     3.628906  4.167192  0.538286
# ...

# %% [markdown]
# #### or

# %% [markdown]
# + reverse the order of rows and slice oof the top 15 rows

# %%
sorted_by_diff[::-1][:15]
# Out:
# gender                                         F         M      diff
# title
# Good, The Bad and The Ugly, The (1966)  3.494949  4.221300  0.726351
# Kentucky Fried Movie, The (1977)        2.878788  3.555147  0.676359
# Dumb & Dumber (1994)                    2.697987  3.336595  0.638608
# Longest Day, The (1962)                 3.411765  4.031447  0.619682
# Cable Guy, The (1996)                   2.250000  2.863787  0.613787
# Evil Dead II (Dead By Dawn) (1987)      3.297297  3.909283  0.611985
# Hidden, The (1987)                      3.137931  3.745098  0.607167
# Rocky III (1982)                        2.361702  2.943503  0.581801
# Caddyshack (1980)                       3.396135  3.969737  0.573602
# For a Few Dollars More (1965)           3.409091  3.953795  0.544704
# Porky's (1981)                          2.296875  2.836364  0.539489
# Animal House (1978)                     3.628906  4.167192  0.538286
# ...

# %%
rating_std_by_title=data.groupby('title')['rating'].std()
rating_std_by_title[:10]
# Out:
# title
# $1,000,000 Duck (1971)               1.092563
# 'Night Mother (1986)                 1.118636
# 'Til There Was You (1997)            1.020159
# 'burbs, The (1989)                   1.107760
# ...And Justice for All (1979)        0.878110
# 1-900 (1994)                         0.707107
# 10 Things I Hate About You (1999)    0.989815
# 101 Dalmatians (1961)                0.982103
# 101 Dalmatians (1996)                1.098717
# 12 Angry Men (1957)                  0.812731
# Name: rating, dtype: float64

# %%
rating_std_by_title=rating_std_by_title.loc[active_titles]
rating_std_by_title.head()
# Out:
# title
# 'burbs, The (1989)                   1.107760
# 10 Things I Hate About You (1999)    0.989815
# 101 Dalmatians (1961)                0.982103
# 101 Dalmatians (1996)                1.098717
# 12 Angry Men (1957)                  0.812731
# Name: rating, dtype: float64

# %%
rating_std_by_title.sort_values(ascending=False)[:10]
# Out:
# title
# Dumb & Dumber (1994)                     1.321333
# Blair Witch Project, The (1999)          1.316368
# Natural Born Killers (1994)              1.307198
# Tank Girl (1995)                         1.277695
# Rocky Horror Picture Show, The (1975)    1.260177
# Eyes Wide Shut (1999)                    1.259624
# Evita (1996)                             1.253631
# Billy Madison (1995)                     1.249970
# Fear and Loathing in Las Vegas (1998)    1.246408
# Bicentennial Man (1999)                  1.245533
# Name: rating, dtype: float64

# %% [markdown]
# #### standard deviation as a measure of disagreement
# + standard deviation shows how spread out values are
# + in the movie rating world, that 'spread' equals to how much people disagreed
# + let's say movie A ratings: `[5, 5, 5, 5, 5]`
#   + everyone agrees this is a masterpiece
#   + low standard deviation: 0
#     + everyone nods in agreement
#     + consistent opinion
# + movie B ratings: `[1, 5, 2, 4, 5]`
#   + here we have widely mixed feelings
#   + high standard deviation says:-
#     + people didn't feel the same about it
#     + there is no strong consesus
#     + some said it's a masterpiece, some said 'meh'

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

sorted_by_diff.head(20).plot(kind='barh', y='diff', legend=False, color='deeppink')
plt.title('Top movies women rated higher than men')
plt.xlabel('Average rating difference(M-F)')
plt.ylabel('Movie title')
plt.tight_layout()
plt.show()

# %%
sorted_by_diff.tail(20).plot(kind='barh', y='diff', legend=False, color='orangered')
plt.title('Top Movies Men Rated Higher Than Women')
plt.xlabel('Average Rating Difference (M - F)')
plt.ylabel('Movie Title')
plt.tight_layout()
plt.show()
